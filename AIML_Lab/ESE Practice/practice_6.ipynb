# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/YBI-Foundation/Dataset/refs/heads/main/Bike%20Sharing%20Original%20Data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Season             731 non-null    object
#  1   Year               731 non-null    int64
#  2   Month              731 non-null    object
#  3   Holiday            731 non-null    object
#  4   Weekday            731 non-null    object
#  5   Working Day        731 non-null    object
#  6   Weather Situation  731 non-null    object
#  7   Temperature        731 non-null    float64
#  8   Humidity           731 non-null    float64
#  9   Wind Speed         731 non-null    float64
#  10  Rider              731 non-null    int64
#  11  Day Since          731 non-null    int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 68.7+ KB

# %%
df.head()
# Out:
#    Year Month     Holiday Weekday     Working Day Weather Situation  \
# 0  2011   JAN  NO HOLIDAY     SAT  NO WORKING DAY             MISTY
# 1  2011   JAN  NO HOLIDAY     SUN  NO WORKING DAY             MISTY
# 2  2011   JAN  NO HOLIDAY     MON     WORKING DAY              GOOD
# 3  2011   JAN  NO HOLIDAY     TUE     WORKING DAY              GOOD
# 4  2011   JAN  NO HOLIDAY     WED     WORKING DAY              GOOD
#
#    Temperature  Humidity  Wind Speed  Rider  Day Since  Season_FALL  \
# 0     8.175849   80.5833   10.749882    985          0        False
# 1     9.083466   69.6087   16.652113    801          1        False
# 2     1.229108   43.7273   16.636703   1349          2        False
# 3     1.400000   59.0435   10.739832   1562          3        False
# 4     2.666979   43.6957   12.522300   1600          4        False
#
#    Season_SPRING  Season_SUMMER  Season_WINTER
# 0          False          False           True
# 1          False          False           True
# ...

# %%
df["Season"].unique()
# Out:
# array(['WINTER', 'SPRING', 'SUMMER', 'FALL'], dtype=object)

# %%
df = pd.get_dummies(df, columns = ["Season"])

# %%
df["Weather Situation"].unique()
# Out:
# array([0, 1, 2])

# %%
df = df.replace({"MISTY" : 0, "GOOD" : 1, "RAIN/SNOW/STORM" : 2})
